# %% [markdown]
# <a href="https://colab.research.google.com/github/viklearnsai-hub/Machine_Learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
from tensorflow.keras import layers,models
from tensorflow.keras.datasets import cifar100

# %%
(xtrain,ytrain),(xtest,ytest) = cifar100.load_data()

# %%
x_train = xtrain.astype('float32')/255.0
x_test = xtest.astype('float32')/255.0

# %%
x_train
# Out:
# array([[[[0.23137255, 0.24313726, 0.24705882],
#          [0.16862746, 0.18039216, 0.1764706 ],
#          [0.19607843, 0.1882353 , 0.16862746],
#          ...,
#          [0.61960787, 0.5176471 , 0.42352942],
#          [0.59607846, 0.49019608, 0.4       ],
#          [0.5803922 , 0.4862745 , 0.40392157]],
#
#         [[0.0627451 , 0.07843138, 0.07843138],
#          [0.        , 0.        , 0.        ],
#          [0.07058824, 0.03137255, 0.        ],
#          ...,
#          [0.48235294, 0.34509805, 0.21568628],
#          [0.46666667, 0.3254902 , 0.19607843],
#          [0.47843137, 0.34117648, 0.22352941]],
#
#         [[0.09803922, 0.09411765, 0.08235294],
#          [0.0627451 , 0.02745098, 0.        ],
#          [0.19215687, 0.10588235, 0.03137255],
#          ...,
#          [0.4627451 , 0.32941177, 0.19607843],
#          [0.47058824, 0.32941177, 0.19607843],
#          [0.42745098, 0.28627452, 0.16470589]],
#
#         ...,
#
# ...

# %%
x_test
# Out:
# array([[[[0.61960787, 0.4392157 , 0.19215687],
#          [0.62352943, 0.43529412, 0.18431373],
#          [0.64705884, 0.45490196, 0.2       ],
#          ...,
#          [0.5372549 , 0.37254903, 0.14117648],
#          [0.49411765, 0.35686275, 0.14117648],
#          [0.45490196, 0.33333334, 0.12941177]],
#
#         [[0.59607846, 0.4392157 , 0.2       ],
#          [0.5921569 , 0.43137255, 0.15686275],
#          [0.62352943, 0.44705883, 0.1764706 ],
#          ...,
#          [0.53333336, 0.37254903, 0.12156863],
#          [0.49019608, 0.35686275, 0.1254902 ],
#          [0.46666667, 0.34509805, 0.13333334]],
#
#         [[0.5921569 , 0.43137255, 0.18431373],
#          [0.5921569 , 0.42745098, 0.12941177],
#          [0.61960787, 0.43529412, 0.14117648],
#          ...,
#          [0.54509807, 0.38431373, 0.13333334],
#          [0.50980395, 0.37254903, 0.13333334],
#          [0.47058824, 0.34901962, 0.12941177]],
#
#         ...,
#
# ...

# %%
model = models.Sequential()

# %%
model.add(layers.Conv2D(32,(3,3),activation="relu"))
model.add(layers.MaxPooling2D((2,2)))

# %%
model.add(layers.Conv2D(64,(3,3),activation="relu"))
model.add(layers.MaxPooling2D((2,2)))

# %%
model.add(layers.Conv2D(128,(3,3),activation="relu"))
model.add(layers.MaxPooling2D((2,2)))

# %%
model.add(layers.Flatten())
model.add(layers.Dense(250,activation="relu"))
model.add(layers.Dense(100,activation="softmax"))

# %%
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
model.fit(x_train,ytrain,epochs=100,batch_size=64,validation_data=(x_test,ytest))
# Out:
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5077 - loss: 1.8145 - val_accuracy: 0.3891 - val_loss: 2.4680
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5241 - loss: 1.7463 - val_accuracy: 0.4003 - val_loss: 2.4713
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5459 - loss: 1.6589 - val_accuracy: 0.3930 - val_loss: 2.5311
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5571 - loss: 1.6005 - val_accuracy: 0.3866 - val_loss: 2.5386
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5725 - loss: 1.5361 - val_accuracy: 0.3818 - val_loss: 2.5994
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5887 - loss: 1.4733 - val_accuracy: 0.3884 - val_loss: 2.6039
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6054 - loss: 1.4098 - val_accuracy: 0.3929 - val_loss: 2.6403
# Epoch 8/100
# ...

# %%
test_loss,test_acc = model.evaluate(x_test,ytest)
print(f"Test accuracy: {test_acc}")
print(f"Loss accuracy: {test_loss}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3452 - loss: 10.7708
# Test accuracy: 0.33880001306533813
# Loss accuracy: 10.803751945495605
