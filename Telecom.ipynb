# %% [markdown]
# <a href="https://colab.research.google.com/github/viklearnsai-hub/Machine_Learning/blob/main/Telecom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install  tensorflow

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
X = df.iloc[:,1:18]

# %%
X.head(1)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod
# 0              Yes  Electronic check

# %%
Y= df.iloc[:,20]

# %%
Y.head(1)
# Out:
# 0    No
# Name: Churn, dtype: object

# %%
X_encoded = pd.get_dummies( X, drop_first=True ,dtype=int)

# %%
X_encoded.head(10)
# Out:
#    SeniorCitizen  tenure  gender_Male  Partner_Yes  Dependents_Yes  \
# 0              0       1            0            1               0
# 1              0      34            1            0               0
# 2              0       2            1            0               0
# 3              0      45            1            0               0
# 4              0       2            0            0               0
# 5              0       8            0            0               0
# 6              0      22            1            0               1
# 7              0      10            0            0               0
# 8              0      28            0            1               0
# 9              0      62            1            0               1
#
#    PhoneService_Yes  MultipleLines_No phone service  MultipleLines_Yes  \
# 0                 0                               1                  0
# 1                 1                               0                  0
# ...

# %%
parnterDummies = pd.get_dummies(X['Partner'],dtype=int,drop_first=True)

# %%
phoneServiceDummy = pd.get_dummies(X['PhoneService'],dtype=int,drop_first=True)

# %%
multiPhonesDummy = pd.get_dummies(X['MultipleLines'],dtype=int,drop_first=True)

# %% [markdown]
# Index(['customerID', '**gender**', 'SeniorCitizen', '**Partner**', '**Dependents**',
#        'tenure', '**PhoneService**', '**MultipleLines**', '**InternetService**',
#        '**OnlineSecurity**', '**OnlineBackup**', '**DeviceProtection**', '**TechSupport**',
#        '**StreamingTV**', '**StreamingMovies**', '**Contract**', '**PaperlessBilling**',
#        '**PaymentMethod**', '**MonthlyCharges**', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
genderDummy = pd.get_dummies(X['gender'],dtype=int,drop_first=True)
parnterDummies = pd.get_dummies(X['Partner'],dtype=int,drop_first=True)
dependentDummies = pd.get_dummies(X['Dependents'],dtype=int,drop_first=True)
phoneServiceDummy = pd.get_dummies(X['PhoneService'],dtype=int,drop_first=True)
multiPhonesDummy = pd.get_dummies(X['MultipleLines'],dtype=int,drop_first=True)
internetServiceDummy = pd.get_dummies(X['InternetService'],dtype=int,drop_first=True)
onlineSecurityDummy = pd.get_dummies(X['OnlineSecurity'],dtype=int,drop_first=True)
onlineBackupDummy = pd.get_dummies(X['OnlineBackup'],dtype=int,drop_first=True)
deviceProtectionDummy = pd.get_dummies(X['DeviceProtection'],dtype=int,drop_first=True)
techSupportDummy = pd.get_dummies(X['TechSupport'],dtype=int,drop_first=True)
streamingTVDummy = pd.get_dummies(X['StreamingTV'],dtype=int,drop_first=True)
streamingMoviesDummy = pd.get_dummies(X['StreamingMovies'],dtype=int,drop_first=True)
contractDummy = pd.get_dummies(X['Contract'],dtype=int,drop_first=True)
paperlessBillingDummy = pd.get_dummies(X['PaperlessBilling'],dtype=int,drop_first=True)
paymentMethodDummy = pd.get_dummies(X['PaymentMethod'],dtype=int,drop_first=True)

# %%
X= X.drop(['gender','Partner','Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod'],axis=1)

# %%
X = pd.concat([X,genderDummy,parnterDummies,dependentDummies,phoneServiceDummy,multiPhonesDummy,internetServiceDummy,onlineSecurityDummy,onlineBackupDummy,deviceProtectionDummy,techSupportDummy,streamingTVDummy,streamingMoviesDummy,contractDummy,paperlessBillingDummy,paymentMethodDummy],axis=1)

# %%
X.columns
# Out:
# Index(['SeniorCitizen', 'tenure', 'Male', 'Yes', 'Yes', 'Yes',
#        'No phone service', 'Yes', 'Fiber optic', 'No', 'No internet service',
#        'Yes', 'No internet service', 'Yes', 'No internet service', 'Yes',
#        'No internet service', 'Yes', 'No internet service', 'Yes',
#        'No internet service', 'Yes', 'One year', 'Two year', 'Yes',
#        'Credit card (automatic)', 'Electronic check', 'Mailed check'],
#       dtype='object')
